# %% [markdown]
# <a href="https://colab.research.google.com/github/anshsaboo/financial-fraud-detection/blob/notebooks/cleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
url = "https://raw.githubusercontent.com/anshsaboo/financial-fraud-detection/refs/heads/dataset/bank_transactions_data_2.csv"
df = pd.read_csv(url)

# %%
df['TransactionDate']=pd.to_datetime(df['TransactionDate'])
df['PreviousTransactionDate']=pd.to_datetime(df['PreviousTransactionDate'])

# %%
df.rename(columns={'IP Address':'IPAddress'},inplace=True)

# %%
df.sort_values(by='TransactionDate',inplace=True)

# %%
str_cols=df.select_dtypes(include='object').columns
df[str_cols]=df[str_cols].apply(lambda x:x.str.strip())

# %%
df.to_csv("cleaned_bank_transaction.csv",index=False)
print("Cleaned dataset saved as 'cleaned_bank_transaction.csv'")
# Out:
# Cleaned dataset saved as 'cleaned_bank_transaction.csv'
